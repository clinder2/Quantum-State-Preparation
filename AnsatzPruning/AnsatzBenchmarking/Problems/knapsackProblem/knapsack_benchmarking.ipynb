# %% [markdown]
# Imports

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import time
import pathlib
import sys

project_root = pathlib.Path().resolve().parents[3]
sys.path.append(str(project_root))

from qiskit import QuantumCircuit
from qiskit.quantum_info import SparsePauliOp
from qiskit.primitives import StatevectorEstimator as Estimator
from qiskit.circuit.library import efficient_su2
from qiskit.circuit import ParameterVector

from KnapsackHamiltonian import buildKnapsackHamiltonian
from AnsatzPruning.MomentumBuilder import MomentumBuilder
from AnsatzPruning.MomentumMonteCarlo import momentum_monte_carlo
from AnsatzPruning.Utilities import cost_func

sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (10,6)

print("Imports successful.")
# Out:
# Imports successful.

# %% [markdown]
# Define the Knapsack Probelm

# %%
values = [6, 10, 12]
weights = [1, 2, 3]
W = 3
P = 20.0

H = buildKnapsackHamiltonian(values, weights, W, P)
observables = [*H.paulis, H]

n = len(values)
print(f"{n}-qubit knapsack Hamiltonian loaded.")
# Out:
# 3-qubit knapsack Hamiltonian loaded.

# %% [markdown]
# Energy Evaluation

# %%
def evaluate_energy(params, circuit, observables):
    est = Estimator()
    cost = cost_func(params, circuit, observables, est)
    return cost[-1]

# %% [markdown]
# EfficientSU2 Benchmarking

# %%
def benchmark_efficient_su2(H, observables, n):

    circuit = QuantumCircuit(n)
    su2 = efficient_su2(n, reps=2)
    circuit = circuit.compose(su2)

    num_params = len(circuit.parameters)
    params = np.random.random(num_params)

    start = time.time()
    energy = evaluate_energy(params, circuit, observables)
    end = time.time()

    return energy, num_params, end - start

# %% [markdown]
# Momentum Builder Benchmarking

# %%
def benchmark_momentum_builder(H, observables, n):

    estimator = Estimator()
    base_circuit = QuantumCircuit(n)
    ansatz = QuantumCircuit(n)

    params = []
    inds = []
    theta = ParameterVector("theta", n)

    for i in range(n):
        ansatz.rx(theta[i], i)
        params.append(1)
        inds.append(i)

    start = time.time()
    final_circuit = MomentumBuilder(
        params,
        inds,
        ansatz,
        base_circuit,
        observables,
        estimator,
        beta1=0.9,
        beta2=0.99,
        iters=2
    )
    end = time.time()

    num_params = len(final_circuit.parameters)
    rand_params = np.random.random(num_params)

    energy = evaluate_energy(rand_params, final_circuit, observables)

    return energy, num_params, end - start

# %% [markdown]
# Momentum MonteCarlo Benchmarking

# %%
def benchmark_momentum_montecarlo(H, observables, n):

    estimator = Estimator()
    base_circuit = QuantumCircuit(n)
    ansatz = QuantumCircuit(n)

    params = []
    inds = []
    theta = ParameterVector("theta", n)

    for i in range(n):
        ansatz.rx(theta[i], i)
        params.append(1)
        inds.append(i)

    start = time.time()

    final_circuit, final_params = momentum_monte_carlo(
        params,
        inds,
        ansatz,
        base_circuit,
        H,                     # pass H here
        estimator,
        beta1=0.9,
        beta2=0.99,
        iters=2,
        optimization_runs=50
    )

    end = time.time()

    energy = evaluate_energy(final_params, final_circuit, observables)

    return energy, len(final_params), end - start

# %% [markdown]
# Running Multiple Trials

# %%
from KanpsackProblems import KnapsackProblemSet

TRIALS = 10
results = []

problem_set = KnapsackProblemSet()
problems = problem_set.createProblemSets()

print("="*70)
print("RUNNING BENCHMARKS")
print("="*70)

for problem_index, (H, expected) in enumerate(problems):

    n = H.num_qubits
    observables = [*H.paulis, H]

    print(f"\nProblem {problem_index+1} | Qubits: {n}")
    print("-"*50)

    for trial in range(TRIALS):

        print(f"Trial {trial+1}/{TRIALS}", end=" | ")

        # EfficientSU2 (always safe)
        e, p, t = benchmark_efficient_su2(H, observables, n)
        results.append({
            "problem_id": problem_index+1,
            "ansatz_type": "EfficientSU2",
            "energy": e,
            "params": p,
            "time": t
        })

        # Only run Momentum methods if n >= 2
        if n >= 2:

            e, p, t = benchmark_momentum_builder(H, observables, n)
            results.append({
                "problem_id": problem_index+1,
                "ansatz_type": "Momentum",
                "energy": e,
                "params": p,
                "time": t
            })

            e, p, t = benchmark_momentum_montecarlo(H, observables, n)
            results.append({
                "problem_id": problem_index+1,
                "ansatz_type": "MomentumMonteCarlo",
                "energy": e,
                "params": p,
                "time": t
            })

        print("✓")

df = pd.DataFrame(results)

print("\n" + "="*70)
print(f"Completed {len(df)} total runs")
print("="*70)

df.head()
# Out:
# ======================================================================
# RUNNING BENCHMARKS
# ======================================================================
#
# Problem 1 | Qubits: 1
# --------------------------------------------------
# Trial 1/10 | ✓
# Trial 2/10 | ✓
# Trial 3/10 | ✓
# Trial 4/10 | ✓
# Trial 5/10 | ✓
# Trial 6/10 | ✓
# Trial 7/10 | ✓
# Trial 8/10 | ✓
# Trial 9/10 | ✓
# Trial 10/10 | ✓
#
# Problem 2 | Qubits: 1
# --------------------------------------------------
# Trial 1/10 | ✓
# Trial 2/10 | ✓
# Trial 3/10 | ✓
# Trial 4/10 | ✓
# Trial 5/10 | ✓
# Trial 6/10 | ✓
# Trial 7/10 | ✓
# Trial 8/10 | ✓
# Trial 9/10 | ✓
# Trial 10/10 | ✓
#
# Problem 3 | Qubits: 2
# --------------------------------------------------
# Trial 1/10 | Energy after MomentumBuilder:  66.546766141902
# Energy after MomentumBuilder and Monte Carlo:  13.300098422444993
# ✓
# Trial 2/10 | Energy after MomentumBuilder:  66.546766141902
# Energy after MomentumBuilder and Monte Carlo:  16.48066592422282
# ✓
# Trial 3/10 | Energy after MomentumBuilder:  66.546766141902
# Energy after MomentumBuilder and Monte Carlo:  31.66919911147081
# ✓
# Trial 4/10 | Energy after MomentumBuilder:  66.546766141902
# Energy after MomentumBuilder and Monte Carlo:  6.605905374900074
# ✓
# Trial 5/10 | Energy after MomentumBuilder:  66.546766141902
# Energy after MomentumBuilder and Monte Carlo:  6.288154876061471
# ✓
# Trial 6/10 | Energy after MomentumBuilder:  66.546766141902
# Energy after MomentumBuilder and Monte Carlo:  30.328115656435806
# ✓
# Trial 7/10 | Energy after MomentumBuilder:  66.546766141902
# Energy after MomentumBuilder and Monte Carlo:  10.829916834410849
# ✓
# Trial 8/10 | Energy after MomentumBuilder:  66.546766141902
# Energy after MomentumBuilder and Monte Carlo:  15.29642415552371
# ✓
# Trial 9/10 | Energy after MomentumBuilder:  66.546766141902
# Energy after MomentumBuilder and Monte Carlo:  0.8288546059033752
# ✓
# Trial 10/10 | Energy after MomentumBuilder:  66.546766141902
# Energy after MomentumBuilder and Monte Carlo:  14.380767563984842
# ✓
#
# Problem 4 | Qubits: 2
# --------------------------------------------------
# Trial 1/10 | Energy after MomentumBuilder:  39.655413743615895
# Energy after MomentumBuilder and Monte Carlo:  -8.024705223527786
# ✓
# Trial 2/10 | Energy after MomentumBuilder:  39.655413743615895
# Energy after MomentumBuilder and Monte Carlo:  -12.938189654913028
# ✓
# Trial 3/10 | Energy after MomentumBuilder:  39.655413743615895
# Energy after MomentumBuilder and Monte Carlo:  -12.887982661909913
# ✓
# Trial 4/10 | Energy after MomentumBuilder:  39.655413743615895
# Energy after MomentumBuilder and Monte Carlo:  -10.113018838252966
# ✓
# Trial 5/10 | Energy after MomentumBuilder:  39.655413743615895
# Energy after MomentumBuilder and Monte Carlo:  -12.31483656764711
# ✓
# Trial 6/10 | Energy after MomentumBuilder:  39.655413743615895
# Energy after MomentumBuilder and Monte Carlo:  -12.516958393045417
# ✓
# Trial 7/10 | Energy after MomentumBuilder:  39.655413743615895
# Energy after MomentumBuilder and Monte Carlo:  1.4615841064072796
# ✓
# Trial 8/10 | Energy after MomentumBuilder:  39.655413743615895
# Energy after MomentumBuilder and Monte Carlo:  -12.811903863526503
# ✓
# Trial 9/10 | Energy after MomentumBuilder:  39.655413743615895
# Energy after MomentumBuilder and Monte Carlo:  -12.856514306876662
# ✓
# Trial 10/10 | Energy after MomentumBuilder:  39.655413743615895
# Energy after MomentumBuilder and Monte Carlo:  -6.5092854964467435
# ✓
#
# Problem 5 | Qubits: 3
# --------------------------------------------------
# Trial 1/10 | Energy after MomentumBuilder:  132.6847585340327
# Energy after MomentumBuilder and Monte Carlo:  31.195699146298605
# ✓
# Trial 2/10 | Energy after MomentumBuilder:  132.6847585340327
# Energy after MomentumBuilder and Monte Carlo:  38.38749785756088
# ✓
# Trial 3/10 | Energy after MomentumBuilder:  132.6847585340327
# Energy after MomentumBuilder and Monte Carlo:  20.83616468378394
# ✓
# Trial 4/10 | Energy after MomentumBuilder:  132.6847585340327
# Energy after MomentumBuilder and Monte Carlo:  28.721613441105095
# ✓
# Trial 5/10 | Energy after MomentumBuilder:  132.6847585340327
# Energy after MomentumBuilder and Monte Carlo:  43.49113116619602
# ✓
# Trial 6/10 | Energy after MomentumBuilder:  132.6847585340327
# Energy after MomentumBuilder and Monte Carlo:  27.596680159122457
# ✓
# Trial 7/10 | Energy after MomentumBuilder:  132.6847585340327
# Energy after MomentumBuilder and Monte Carlo:  28.675181685786676
# ✓
# Trial 8/10 | Energy after MomentumBuilder:  132.6847585340327
# Energy after MomentumBuilder and Monte Carlo:  19.277137553114613
# ✓
# Trial 9/10 | Energy after MomentumBuilder:  132.6847585340327
# Energy after MomentumBuilder and Monte Carlo:  2.182389919123792
# ✓
# Trial 10/10 | Energy after MomentumBuilder:  132.6847585340327
# Energy after MomentumBuilder and Monte Carlo:  39.09989765670443
# ✓
#
# Problem 6 | Qubits: 4
# --------------------------------------------------
# Trial 1/10 | Energy after MomentumBuilder:  176.09734138691334
# Energy after MomentumBuilder and Monte Carlo:  63.83508413906074
# ✓
# Trial 2/10 | Energy after MomentumBuilder:  176.09734138691334
# Energy after MomentumBuilder and Monte Carlo:  44.98237440598998
# ✓
# Trial 3/10 | Energy after MomentumBuilder:  176.09734138691334
# Energy after MomentumBuilder and Monte Carlo:  56.078995436164675
# ✓
# Trial 4/10 | Energy after MomentumBuilder:  176.09734138691334
# Energy after MomentumBuilder and Monte Carlo:  38.6869708353735
# ✓
# Trial 5/10 | Energy after MomentumBuilder:  176.09734138691334
# Energy after MomentumBuilder and Monte Carlo:  57.31683660573861
# ✓
# Trial 6/10 | Energy after MomentumBuilder:  176.09734138691334
# Energy after MomentumBuilder and Monte Carlo:  45.67692901955996
# ✓
# Trial 7/10 | Energy after MomentumBuilder:  176.09734138691334
# Energy after MomentumBuilder and Monte Carlo:  67.56148314722932
# ✓
# Trial 8/10 | Energy after MomentumBuilder:  176.09734138691334
# Energy after MomentumBuilder and Monte Carlo:  65.2024365433352
# ✓
# Trial 9/10 | Energy after MomentumBuilder:  176.09734138691334
# Energy after MomentumBuilder and Monte Carlo:  87.41750885234411
# ✓
# Trial 10/10 | Energy after MomentumBuilder:  176.09734138691334
# Energy after MomentumBuilder and Monte Carlo:  53.48560761324134
# ✓
#
# Problem 7 | Qubits: 5
# --------------------------------------------------
# Trial 1/10 | Energy after MomentumBuilder:  159.35197193361705
# Energy after MomentumBuilder and Monte Carlo:  98.47540617076518
# ✓
# Trial 2/10 | Energy after MomentumBuilder:  159.35197193361705
# Energy after MomentumBuilder and Monte Carlo:  56.293211580355205
# ✓
# Trial 3/10 | Energy after MomentumBuilder:  159.35197193361705
# Energy after MomentumBuilder and Monte Carlo:  98.7048506181069
# ✓
# Trial 4/10 | Energy after MomentumBuilder:  159.35197193361705
# Energy after MomentumBuilder and Monte Carlo:  115.61009395662185
# ✓
# Trial 5/10 | Energy after MomentumBuilder:  159.35197193361705
# Energy after MomentumBuilder and Monte Carlo:  92.43236346969303
# ✓
# Trial 6/10 | Energy after MomentumBuilder:  159.35197193361705
# Energy after MomentumBuilder and Monte Carlo:  105.74733436691449
# ✓
# Trial 7/10 | Energy after MomentumBuilder:  159.35197193361705
# Energy after MomentumBuilder and Monte Carlo:  74.16537054588517
# ✓
# Trial 8/10 | Energy after MomentumBuilder:  159.35197193361705
# Energy after MomentumBuilder and Monte Carlo:  51.907738915542666
# ✓
# Trial 9/10 | Energy after MomentumBuilder:  159.35197193361705
# Energy after MomentumBuilder and Monte Carlo:  96.09405959848328
# ✓
# Trial 10/10 | Energy after MomentumBuilder:  159.35197193361705
# Energy after MomentumBuilder and Monte Carlo:  81.56466024190217
# ✓
#
# Problem 8 | Qubits: 4
# --------------------------------------------------
# Trial 1/10 | Energy after MomentumBuilder:  65.12801566072693
# Energy after MomentumBuilder and Monte Carlo:  27.47862789277672
# ✓
# Trial 2/10 | Energy after MomentumBuilder:  65.12801566072693
# Energy after MomentumBuilder and Monte Carlo:  33.59122160164423
# ✓
# Trial 3/10 | Energy after MomentumBuilder:  65.12801566072693
# Energy after MomentumBuilder and Monte Carlo:  27.699162618921715
# ✓
# Trial 4/10 | Energy after MomentumBuilder:  65.12801566072693
# Energy after MomentumBuilder and Monte Carlo:  9.41811558651507
# ✓
# Trial 5/10 | Energy after MomentumBuilder:  65.12801566072693
# Energy after MomentumBuilder and Monte Carlo:  14.05299879909727
# ✓
# Trial 6/10 | Energy after MomentumBuilder:  65.12801566072693
# Energy after MomentumBuilder and Monte Carlo:  26.95712793201304
# ✓
# Trial 7/10 | Energy after MomentumBuilder:  65.12801566072693
# Energy after MomentumBuilder and Monte Carlo:  30.942689449133542
# ✓
# Trial 8/10 | Energy after MomentumBuilder:  65.12801566072693
# Energy after MomentumBuilder and Monte Carlo:  29.91419647610496
# ✓
# Trial 9/10 | Energy after MomentumBuilder:  65.12801566072693
# Energy after MomentumBuilder and Monte Carlo:  26.73115035844172
# ✓
# Trial 10/10 | Energy after MomentumBuilder:  65.12801566072693
# Energy after MomentumBuilder and Monte Carlo:  30.167780875406788
# ✓
#
# Problem 9 | Qubits: 4
# --------------------------------------------------
# Trial 1/10 | Energy after MomentumBuilder:  113.65292013504329
# Energy after MomentumBuilder and Monte Carlo:  64.6901505340202
# ✓
# Trial 2/10 | Energy after MomentumBuilder:  113.65292013504329
# Energy after MomentumBuilder and Monte Carlo:  59.37516950286335
# ✓
# Trial 3/10 | Energy after MomentumBuilder:  113.65292013504329
# Energy after MomentumBuilder and Monte Carlo:  50.0508926982961
# ✓
# Trial 4/10 | Energy after MomentumBuilder:  113.65292013504329
# Energy after MomentumBuilder and Monte Carlo:  30.427786057414668
# ✓
# Trial 5/10 | Energy after MomentumBuilder:  113.65292013504329
# Energy after MomentumBuilder and Monte Carlo:  46.85676574392592
# ✓
# Trial 6/10 | Energy after MomentumBuilder:  113.65292013504329
# Energy after MomentumBuilder and Monte Carlo:  48.570306314690846
# ✓
# Trial 7/10 | Energy after MomentumBuilder:  113.65292013504329
# Energy after MomentumBuilder and Monte Carlo:  29.20643960878152
# ✓
# Trial 8/10 | Energy after MomentumBuilder:  113.65292013504329
# Energy after MomentumBuilder and Monte Carlo:  48.525150627409865
# ✓
# Trial 9/10 | Energy after MomentumBuilder:  113.65292013504329
# Energy after MomentumBuilder and Monte Carlo:  32.883100099354486
# ✓
# Trial 10/10 | Energy after MomentumBuilder:  113.65292013504329
# Energy after MomentumBuilder and Monte Carlo:  31.711254078120916
# ✓
#
# Problem 10 | Qubits: 4
# --------------------------------------------------
# Trial 1/10 | Energy after MomentumBuilder:  80.22635830701843
# Energy after MomentumBuilder and Monte Carlo:  42.48912404872105
# ✓
# Trial 2/10 | Energy after MomentumBuilder:  80.22635830701843
# Energy after MomentumBuilder and Monte Carlo:  44.69633647729762
# ✓
# Trial 3/10 | Energy after MomentumBuilder:  80.22635830701843
# Energy after MomentumBuilder and Monte Carlo:  38.62847372729595
# ✓
# Trial 4/10 | Energy after MomentumBuilder:  80.22635830701843
# Energy after MomentumBuilder and Monte Carlo:  55.81679848113852
# ✓
# Trial 5/10 | Energy after MomentumBuilder:  80.22635830701843
# Energy after MomentumBuilder and Monte Carlo:  42.42066759132496
# ✓
# Trial 6/10 | Energy after MomentumBuilder:  80.22635830701843
# Energy after MomentumBuilder and Monte Carlo:  51.177672071427565
# ✓
# Trial 7/10 | Energy after MomentumBuilder:  80.22635830701843
# Energy after MomentumBuilder and Monte Carlo:  37.348371819258915
# ✓
# Trial 8/10 | Energy after MomentumBuilder:  80.22635830701843
# Energy after MomentumBuilder and Monte Carlo:  31.787195997291278
# ✓
# Trial 9/10 | Energy after MomentumBuilder:  80.22635830701843
# Energy after MomentumBuilder and Monte Carlo:  50.700697841433936
# ✓
# Trial 10/10 | Energy after MomentumBuilder:  80.22635830701843
# Energy after MomentumBuilder and Monte Carlo:  61.220852953914154
# ✓
#
# Problem 11 | Qubits: 8
# --------------------------------------------------
# Trial 1/10 | Energy after MomentumBuilder:  47.40629308959691
# Energy after MomentumBuilder and Monte Carlo:  14.358584435257628
# ✓
# Trial 2/10 | Energy after MomentumBuilder:  47.40629308959691
# Energy after MomentumBuilder and Monte Carlo:  9.349394316407837
# ✓
# Trial 3/10 | Energy after MomentumBuilder:  47.40629308959691
# Energy after MomentumBuilder and Monte Carlo:  12.56350312478921
# ✓
# Trial 4/10 | Energy after MomentumBuilder:  47.40629308959691
# Energy after MomentumBuilder and Monte Carlo:  4.673769108502416
# ✓
# Trial 5/10 | Energy after MomentumBuilder:  47.40629308959691
# Energy after MomentumBuilder and Monte Carlo:  16.363876529675075
# ✓
# Trial 6/10 | Energy after MomentumBuilder:  47.40629308959691
# Energy after MomentumBuilder and Monte Carlo:  13.580202807034174
# ✓
# Trial 7/10 | Energy after MomentumBuilder:  47.40629308959691
# Energy after MomentumBuilder and Monte Carlo:  19.716764751514646
# ✓
# Trial 8/10 | Energy after MomentumBuilder:  47.40629308959691
# Energy after MomentumBuilder and Monte Carlo:  15.340624059709642
# ✓
# Trial 9/10 | Energy after MomentumBuilder:  47.40629308959691
# Energy after MomentumBuilder and Monte Carlo:  6.685374869456618
# ✓
# Trial 10/10 | Energy after MomentumBuilder:  47.40629308959691
# Energy after MomentumBuilder and Monte Carlo:  12.683612209959337
# ✓
#
# Problem 12 | Qubits: 5
# --------------------------------------------------
# Trial 1/10 | Energy after MomentumBuilder:  84.99783086724047
# Energy after MomentumBuilder and Monte Carlo:  28.277959024418525
# ✓
# Trial 2/10 | Energy after MomentumBuilder:  84.99783086724047
# Energy after MomentumBuilder and Monte Carlo:  16.053737233748873
# ✓
# Trial 3/10 | Energy after MomentumBuilder:  84.99783086724047
# Energy after MomentumBuilder and Monte Carlo:  37.15911545395529
# ✓
# Trial 4/10 | Energy after MomentumBuilder:  84.99783086724047
# Energy after MomentumBuilder and Monte Carlo:  39.800434974852806
# ✓
# Trial 5/10 | Energy after MomentumBuilder:  84.99783086724047
# Energy after MomentumBuilder and Monte Carlo:  15.648006824325236
# ✓
# Trial 6/10 | Energy after MomentumBuilder:  84.99783086724047
# Energy after MomentumBuilder and Monte Carlo:  17.354738854773288
# ✓
# Trial 7/10 | Energy after MomentumBuilder:  84.99783086724047
# Energy after MomentumBuilder and Monte Carlo:  27.79260852209901
# ✓
# Trial 8/10 | Energy after MomentumBuilder:  84.99783086724047
# Energy after MomentumBuilder and Monte Carlo:  33.02705038298717
# ✓
# Trial 9/10 | Energy after MomentumBuilder:  84.99783086724047
# Energy after MomentumBuilder and Monte Carlo:  17.249323241077054
# ✓
# Trial 10/10 | Energy after MomentumBuilder:  84.99783086724047
# Energy after MomentumBuilder and Monte Carlo:  30.06285012803005
# ✓
#
# ======================================================================
# Completed 320 total runs
# ======================================================================
#    problem_id   ansatz_type      energy  params      time
# 0           1  EfficientSU2  225.432426       6  0.014641
# 1           1  EfficientSU2  357.534103       6  0.001606
# 2           1  EfficientSU2  214.292227       6  0.006562
# 3           1  EfficientSU2  200.969610       6  0.000000
# 4           1  EfficientSU2  399.425208       6  0.008054

# %% [markdown]
# Summary Statistics

# %%
summary = df.groupby("ansatz_type").agg({
    "energy":["mean","std","min","max"],
    "time":["mean","std"],
    "params":["mean","std"]
})

summary
# Out:
#                         energy                                        time  \
#                           mean        std        min         max      mean
# ansatz_type
# EfficientSU2        173.464021  78.424323  57.893905  450.601621  0.028347
# Momentum            163.374683  60.797867  50.179003  358.573504  0.327657
# MomentumMonteCarlo   33.204768  27.944944 -12.938190  115.610094  1.180630
#
#                              params
#                          std   mean        std
# ansatz_type
# EfficientSU2        0.033863   21.5  11.394382
# Momentum            0.375315    8.1   1.648385
# MomentumMonteCarlo  0.930592    8.1   1.648385

# %% [markdown]
# Main Comparision Plots

# %%
# Visualization 1: Main comparison plots
if len(df) > 0 and "ansatz_type" in df.columns:

    palette = {
        "EfficientSU2": "#e74c3c",
        "Momentum": "#2ecc71",
        "MomentumMonteCarlo": "#3498db"
    }

    fig, axes = plt.subplots(2, 2, figsize=(14, 10))

    # ================================
    # 1. Energy Comparison (Boxplot)
    # ================================
    sns.boxplot(
        data=df,
        x="ansatz_type",
        y="energy",
        hue="ansatz_type",
        palette=palette,
        ax=axes[0, 0],
        legend=False
    )

    axes[0, 0].set_title("Final Energy Comparison", fontsize=14, fontweight="bold")
    axes[0, 0].set_xlabel("Ansatz Type")
    axes[0, 0].set_ylabel("Energy")
    axes[0, 0].grid(True, alpha=0.3)


    # ======================================
    # 2. Optimization Time Comparison
    # ======================================
    sns.boxplot(
        data=df,
        x="ansatz_type",
        y="time",
        hue="ansatz_type",
        palette=palette,
        ax=axes[0, 1],
        legend=False
    )

    axes[0, 1].set_title("Optimization Time Comparison", fontsize=14, fontweight="bold")
    axes[0, 1].set_xlabel("Ansatz Type")
    axes[0, 1].set_ylabel("Time (seconds)")
    axes[0, 1].grid(True, alpha=0.3)


    # ======================================
    # 3. Number of Parameters (Bar Plot)
    # ======================================
    param_stats = df.groupby("ansatz_type")["params"].mean()

    axes[1, 0].bar(
        param_stats.index,
        param_stats.values,
        color=[palette[k] for k in param_stats.index]
    )

    axes[1, 0].set_title("Number of Parameters", fontsize=14, fontweight="bold")
    axes[1, 0].set_xlabel("Ansatz Type")
    axes[1, 0].set_ylabel("Parameters")
    axes[1, 0].grid(True, alpha=0.3, axis="y")


    # ======================================
    # 4. Energy vs Time Trade-off (Scatter)
    # ======================================
    for ansatz in df["ansatz_type"].unique():
        subset = df[df["ansatz_type"] == ansatz]
        axes[1, 1].scatter(
            subset["time"],
            subset["energy"],
            label=ansatz,
            alpha=0.7,
            s=100,
            color=palette[ansatz]
        )

    axes[1, 1].set_title("Energy vs Time Trade-off", fontsize=14, fontweight="bold")
    axes[1, 1].set_xlabel("Time (seconds)")
    axes[1, 1].set_ylabel("Energy")
    axes[1, 1].legend()
    axes[1, 1].grid(True, alpha=0.3)


    plt.tight_layout()
    plt.savefig("ansatz_comparison.png", dpi=300, bbox_inches="tight")
    plt.show()

# %% [markdown]
# Distribution Plots

# %%
fig, axes = plt.subplots(1,2, figsize=(12,4))

sns.histplot(data=df, x="energy", hue="ansatz_type",
             palette=palette, bins=12, ax=axes[0])
axes[0].set_title("Energy Distribution")

sns.histplot(data=df, x="time", hue="ansatz_type",
             palette=palette, bins=12, ax=axes[1])
axes[1].set_title("Time Distribution")

plt.tight_layout()
plt.show()

# %% [markdown]
# Performance Summary Plot

# %%
summary_means = df.groupby("ansatz_type").mean()

metrics = ["energy","time","params"]
x = np.arange(len(metrics))
width = 0.25

fig, ax = plt.subplots(figsize=(10,6))

for i, ansatz in enumerate(summary_means.index):
    ax.bar(x + i*width,
           summary_means.loc[ansatz][metrics],
           width,
           label=ansatz,
           color=palette[ansatz])

ax.set_xticks(x + width)
ax.set_xticklabels(["Energy","Time","Parameters"])
ax.set_title("Performance Metrics Comparison")
ax.legend()

plt.show()

# %% [markdown]
# Improvement Metrics for the Momentum Builder

# %%
means = df.groupby("ansatz_type").mean()

if "Momentum" in means.index and "EfficientSU2" in means.index:
    e_improve = ((means.loc["EfficientSU2","energy"] - means.loc["Momentum","energy"])
                 / abs(means.loc["EfficientSU2","energy"])) * 100
    t_speedup = means.loc["EfficientSU2","time"] / means.loc["Momentum","time"]
    # p_reduction = ((means.loc["EfficientSU2","params"] - means.loc["Momentum","params"])
                #    / means.loc["EfficientSU2","params"]) * 100

    print("======================================")
    print("PERFORMANCE IMPROVEMENTS")
    print("======================================")
    print(f"MomentumBuilder energy improvement: {e_improve:.2f}%")
    print(f"MomentumBuilder speedup: {t_speedup:.2f}x")
    # print(f"MomentumBuilder parameter reduction: {p_reduction:.2f}%")
# Out:
# ======================================
# PERFORMANCE IMPROVEMENTS
# ======================================
# MomentumBuilder energy improvement: 11.27%
# MomentumBuilder speedup: 0.09x

# %% [markdown]
# Improvement Summary for the Momentum Builder and the Momentum MonteCarlo Builder

# %%
means = df.groupby("ansatz_type").mean()

print("======================================")
print("PERFORMANCE IMPROVEMENTS SUMMARY")
print("======================================")

# Ensure all required methods exist
required = ["EfficientSU2", "Momentum", "MomentumMonteCarlo"]

if all(m in means.index for m in required):

    # ==========================
    # Momentum vs EfficientSU2
    # ==========================
    e_improve_m = ((means.loc["EfficientSU2","energy"] - means.loc["Momentum","energy"])
                   / abs(means.loc["EfficientSU2","energy"])) * 100

    t_speedup_m = means.loc["EfficientSU2","time"] / means.loc["Momentum","time"]

    # p_reduction_m = ((means.loc["EfficientSU2","params"] - means.loc["Momentum","params"])
    #                  / means.loc["EfficientSU2","params"]) * 100

    # ======================================
    # MomentumMonteCarlo vs EfficientSU2
    # ======================================
    e_improve_mc = ((means.loc["EfficientSU2","energy"] - means.loc["MomentumMonteCarlo","energy"])
                    / abs(means.loc["EfficientSU2","energy"])) * 100

    t_speedup_mc = means.loc["EfficientSU2","time"] / means.loc["MomentumMonteCarlo","time"]

    # p_reduction_mc = ((means.loc["EfficientSU2","params"] - means.loc["MomentumMonteCarlo","params"])
    #                   / means.loc["EfficientSU2","params"]) * 100

    # ======================================
    # MomentumMonteCarlo vs MomentumBuilder
    # ======================================
    e_improve_mc_vs_m = ((means.loc["Momentum","energy"] - means.loc["MomentumMonteCarlo","energy"])
                         / abs(means.loc["Momentum","energy"])) * 100

    t_ratio_mc_vs_m = means.loc["Momentum","time"] / means.loc["MomentumMonteCarlo","time"]

    # ==========================
    # PRINT RESULTS
    # ==========================

    print("\n--- MomentumBuilder vs EfficientSU2 ---")
    print(f"Energy Improvement:      {e_improve_m:.2f}%")
    print(f"Speedup:                 {t_speedup_m:.2f}x")
    # print(f"Parameter Reduction:     {p_reduction_m:.2f}%")

    print("\n--- MomentumMonteCarlo vs EfficientSU2 ---")
    print(f"Energy Improvement:      {e_improve_mc:.2f}%")
    print(f"Speedup:                 {t_speedup_mc:.2f}x")
    # print(f"Parameter Reduction:     {p_reduction_mc:.2f}%")

    print("\n--- MomentumMonteCarlo vs MomentumBuilder ---")
    print(f"Additional Energy Gain:  {e_improve_mc_vs_m:.2f}%")
    # print(f"Relative Speed Ratio:    {t_ratio_mc_vs_m:.2f}x ( >1 means faster )")

else:
    print("Not all required ansatz types found in results.")
# Out:
# ======================================
# PERFORMANCE IMPROVEMENTS SUMMARY
# ======================================
#
# --- MomentumBuilder vs EfficientSU2 ---
# Energy Improvement:      5.82%
# Speedup:                 0.09x
#
# --- MomentumMonteCarlo vs EfficientSU2 ---
# Energy Improvement:      80.86%
# Speedup:                 0.02x
#
# --- MomentumMonteCarlo vs MomentumBuilder ---
# Additional Energy Gain:  79.68%

# %% [markdown]
# Notes:
# - Add a convergence success rate
# - Make newer harder hamiltonians problems - increase the number of parameters
# - Make the notebook for the new method - from momentummontecarlo.
# - run on a noisy simulator
